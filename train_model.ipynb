# %% [markdown]
# ## Train and Evaulate Model
#
# This notebook will train the model on the spectrogram input data and evaluate on the validation set

# %%
import numpy as np
import matplotlib.pyplot as plt
import pdb
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score
import datetime
import os
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.regularizers import l2
from keras.layers import Reshape, Flatten, TimeDistributed, Bidirectional, BatchNormalization, Dropout, Input, Add, Masking, Conv2D, MaxPooling2D, Concatenate, BatchNormalization, Activation
from keras import Model
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, CSVLogger
from keras.utils import plot_model
import keras.backend as backend

# %% [markdown]
# Define some constants

# %%
BATCH_SIZE = 32

SPECTROGRAM_LEN = 47
SPECTROGRAM_FREQS = 64
NUM_OUTPUT_CLASSES = 3

CONV_OUTPUT_LEN = 30

# %% [markdown]
# Define the common layers of the network

# %%
shared_conv1 = Conv2D(filters=8, kernel_size=3, padding='same')
shared_bn1 = BatchNormalization()
shared_relu1 = Activation('relu')
shared_mp1 = MaxPooling2D(pool_size=4, strides=4)
shared_do1 = Dropout(0.2)

shared_conv2 = Conv2D(filters=16, kernel_size=3, padding='same')
shared_bn2 = BatchNormalization()
shared_relu2 = Activation('relu')
shared_mp2 = MaxPooling2D(pool_size=4, strides=4)
shared_do2 = Dropout(0.2)

shared_flatten = Flatten()

shared_dense1 = Dense(units=CONV_OUTPUT_LEN)
shared_bn4 = BatchNormalization()
shared_relu4 = Activation('relu')

# %% [markdown]
# Define a function to load in the train, test, and validation data. Note that all NREM stages are combined into a single class, so this becomes a 3 class classification problem

# %%
def load_data(data_group):
    data = pickle.load(open('X_%s_spec.pkl' % data_group, 'rb'))
    labels = pickle.load(open('y_%s.pkl' % data_group, 'rb'))

    
    #combine NREM1, NREM2, NREM3, and NREM4 into a single class
    #new class definitions:
    #Wake = 0 originally, this remains the same
    #N1 = 1, N2 = 2, N3 = 3, N4 = 4 originally, now they are all assigned to the label of 1
    #REM = 5 originally, now REM = 2
    #Artifact/Unlabeled: N/A as any such labels were already removed in spectrogram generation
    three_class_labels = []
    for label in labels:
        label = np.array(label)
        label_2_inds = np.where(label==2)[0]
        label_3_inds = np.where(label==3)[0]
        label_4_inds = np.where(label==4)[0]
        label_5_inds = np.where(label==5)[0]

        label[label_2_inds] = 1
        label[label_3_inds] = 1
        label[label_4_inds] = 1
        label[label_5_inds] = 2

        three_class_labels.append(label)

    X1 = []
    X2 = []
    X3 = []
    X4 = []
    X5 = []
    y = []
    #y =
    for i in range(len(data)):
        X1_tmp = data[i][0]
        X2_tmp = data[i][1]
        X3_tmp = data[i][2]
        X4_tmp = data[i][3]
        X5_tmp = data[i][4]

        #make sure the size of the specgrogram is correct before adding it to the array
        #for some reason the third dimension of the spectrogram output is not right
        if (np.shape(X1_tmp)[2] != SPECTROGRAM_LEN) or (np.shape(X2_tmp)[2] != SPECTROGRAM_LEN) or (np.shape(X3_tmp)[2] != SPECTROGRAM_LEN) or (np.shape(X4_tmp)[2] != SPECTROGRAM_LEN) or (np.shape(X5_tmp)[2] != SPECTROGRAM_LEN):
            continue

        X1.append(X1_tmp)
        X2.append(X2_tmp)
        X3.append(X3_tmp)
        X4.append(X4_tmp)
        X5.append(X5_tmp)
        y.append(three_class_labels[i])


    X1 = np.array(X1).reshape(len(X1), SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2)
    X2 = np.array(X2).reshape(len(X2), SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2)
    X3 = np.array(X3).reshape(len(X3), SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2)
    X4 = np.array(X4).reshape(len(X4), SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2)
    X5 = np.array(X5).reshape(len(X5), SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2)
    y = to_categorical(y)

    return X1, X2, X3, X4, X5, y

# %% [markdown]
# Define a function to calculate the f1 score and confusion matrix

# %%
from sklearn.metrics import confusion_matrix, f1_score

def performance_metrics(true, predictions, labels):
    # Loop over each row, and then get the index corresponding to the max probability
    predictions_class = []
    for prediction in predictions:
        for row in prediction:
            predictions_class.append(np.argmax(row))

    true_class = []
    for true_row in true:
        for row in true_row:
            true_class.append(np.argmax(row))

    # Calculate confusion matrix
    conf_mat = confusion_matrix(true_class, predictions_class)
    conf_mat = pd.DataFrame(conf_mat, columns=labels, index=labels)

    # Calculate per class F1 score
    f1 = f1_score(true_class, predictions_class, average=None)
    f1 = pd.Series(f1, index=labels)

    return conf_mat, f1, predictions_class, true_class

# %% [markdown]
# Define functions to build the CNN

# %%
def build_cnn(input):
    #build a cnn per channel
    cnn_output0 = build_cnn_per_channel(input, 0)
    cnn_output1 = build_cnn_per_channel(input, 1)

    #concatenate each channel's output
    cnn_output = Concatenate(axis=1)([cnn_output0, cnn_output1])
    cnn_output = Reshape((1,CONV_OUTPUT_LEN*2))(cnn_output)

    return cnn_output


def build_cnn_per_channel(input, ch):
    cnn_output = shared_conv1(input[:,:,:,ch][...,None])
    cnn_output = shared_bn1(cnn_output)
    cnn_output = shared_relu1(cnn_output)
    cnn_output = shared_mp1(cnn_output)
    cnn_output = shared_do1(cnn_output)
    cnn_output = shared_conv2(cnn_output)
    cnn_output = shared_bn2(cnn_output)
    cnn_output = shared_relu2(cnn_output)
    cnn_output = shared_mp2(cnn_output)
    cnn_output = shared_do2(cnn_output)
    cnn_output = shared_flatten(cnn_output)
    cnn_output = shared_dense1(cnn_output)
    cnn_output = shared_bn4(cnn_output)
    cnn_output = shared_relu4(cnn_output)
    cnn_output = Reshape((1,CONV_OUTPUT_LEN))(cnn_output)

    return cnn_output

# %% [markdown]
# Load in the training and validation data

# %%
X1_train, X2_train, X3_train, X4_train, X5_train, y_train = load_data('train')
X1_val, X2_val, X3_val, X4_val, X5_val, y_val = load_data('val')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 16 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> X1_train, X2_train, X3_train, X4_train, X5_train, y_train = load_data('train')
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> X1_val, X2_val, X3_val, X4_val, X5_val, y_val = load_data('val')
#
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 16 line load_data(data_group)
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> def load_data(data_group):
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     data = pickle.load(open('X_%s_spec.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>     labels = pickle.load(open('y_%s.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     #combine NREM1, NREM2, NREM3, and NREM4 into a single class
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>     #new class definitions:
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>     #Wake = 0 originally, this remains the same
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     #N1 = 1, N2 = 2, N3 = 3, N4 = 4 originally, now they are all assigned to the label of 1
#      <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=9'>10</a>     #REM = 5 originally, now REM = 2
#      <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X16sZmlsZQ%3D%3D?line=10'>11</a>     #Artifact/Unlabeled: N/A as any such labels were already removed in spectrogram generation
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_train_spec.pkl'

# %% [markdown]
# Define the model architecture

# %%
input1 = Input(shape=(SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2))
input2 = Input(shape=(SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2))
input3 = Input(shape=(SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2))
input4 = Input(shape=(SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2))
input5 = Input(shape=(SPECTROGRAM_FREQS, SPECTROGRAM_LEN, 2))

cnn_output1 = build_cnn(input1)
cnn_output2 = build_cnn(input2)
cnn_output3 = build_cnn(input3)
cnn_output4 = build_cnn(input4)
cnn_output5 = build_cnn(input5)

#combine all five outputs into a single input for the LSTM
cnn_concat = Concatenate(axis=1)([cnn_output1, cnn_output2, cnn_output3, cnn_output4, cnn_output5])

lstm_output = Bidirectional(LSTM(15, return_sequences=True, kernel_regularizer=l2(0.01)))(cnn_concat)
lstm_output = Dense(NUM_OUTPUT_CLASSES, activation='softmax')(lstm_output)

model = Model(inputs=[input1, input2, input3, input4, input5], outputs=lstm_output)
model.compile(loss='categorical_crossentropy', metrics=['categorical_accuracy'], optimizer='adam')

print(model.summary())
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_16 (InputLayer)       [(None, 64, 47, 2)]          0         []
#
#  input_17 (InputLayer)       [(None, 64, 47, 2)]          0         []
#
#  input_18 (InputLayer)       [(None, 64, 47, 2)]          0         []
#
#  input_19 (InputLayer)       [(None, 64, 47, 2)]          0         []
#
#  input_20 (InputLayer)       [(None, 64, 47, 2)]          0         []
#
#  tf.__operators__.getitem_6  (None, 64, 47)               0         ['input_16[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 64, 47)               0         ['input_16[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 64, 47)               0         ['input_17[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 64, 47)               0         ['input_17[0][0]']
#  6 (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 64, 47)               0         ['input_18[0][0]']
#  8 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 64, 47)               0         ['input_18[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 64, 47)               0         ['input_19[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 64, 47)               0         ['input_19[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 64, 47)               0         ['input_20[0][0]']
#  6 (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  (None, 64, 47)               0         ['input_20[0][0]']
#  8 (SlicingOpLambda)
#
#  tf.__operators__.getitem_6  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_60[
#  1 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_6  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_62[
#  3 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_6  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_64[
#  5 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_6  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_66[
#  7 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_6  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_68[
#  9 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_7  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_70[
#  1 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_7  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_72[
#  3 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_7  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_74[
#  5 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_7  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_76[
#  7 (SlicingOpLambda)                                                0][0]']
#
#  tf.__operators__.getitem_7  (None, 64, 47, 1)            0         ['tf.__operators__.getitem_78[
#  9 (SlicingOpLambda)                                                0][0]']
#
#  conv2d (Conv2D)             (None, 64, 47, 8)            80        ['tf.__operators__.getitem_61[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_63[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_65[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_67[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_69[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_71[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_73[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_75[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_77[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_79[
#                                                                     0][0]']
#
#  batch_normalization (Batch  (None, 64, 47, 8)            32        ['conv2d[30][0]',
#  Normalization)                                                      'conv2d[31][0]',
#                                                                      'conv2d[32][0]',
#                                                                      'conv2d[33][0]',
#                                                                      'conv2d[34][0]',
#                                                                      'conv2d[35][0]',
#                                                                      'conv2d[36][0]',
#                                                                      'conv2d[37][0]',
#                                                                      'conv2d[38][0]',
#                                                                      'conv2d[39][0]']
#
#  activation (Activation)     (None, 64, 47, 8)            0         ['batch_normalization[30][0]',
#                                                                      'batch_normalization[31][0]',
#                                                                      'batch_normalization[32][0]',
#                                                                      'batch_normalization[33][0]',
#                                                                      'batch_normalization[34][0]',
#                                                                      'batch_normalization[35][0]',
#                                                                      'batch_normalization[36][0]',
#                                                                      'batch_normalization[37][0]',
#                                                                      'batch_normalization[38][0]',
#                                                                      'batch_normalization[39][0]']
#
#  max_pooling2d (MaxPooling2  (None, 16, 11, 8)            0         ['activation[30][0]',
#  D)                                                                  'activation[31][0]',
#                                                                      'activation[32][0]',
#                                                                      'activation[33][0]',
#                                                                      'activation[34][0]',
#                                                                      'activation[35][0]',
#                                                                      'activation[36][0]',
#                                                                      'activation[37][0]',
#                                                                      'activation[38][0]',
#                                                                      'activation[39][0]']
#
#  dropout (Dropout)           (None, 16, 11, 8)            0         ['max_pooling2d[30][0]',
#                                                                      'max_pooling2d[31][0]',
#                                                                      'max_pooling2d[32][0]',
#                                                                      'max_pooling2d[33][0]',
#                                                                      'max_pooling2d[34][0]',
#                                                                      'max_pooling2d[35][0]',
#                                                                      'max_pooling2d[36][0]',
#                                                                      'max_pooling2d[37][0]',
#                                                                      'max_pooling2d[38][0]',
#                                                                      'max_pooling2d[39][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 11, 16)           1168      ['dropout[30][0]',
#                                                                      'dropout[31][0]',
#                                                                      'dropout[32][0]',
#                                                                      'dropout[33][0]',
#                                                                      'dropout[34][0]',
#                                                                      'dropout[35][0]',
#                                                                      'dropout[36][0]',
#                                                                      'dropout[37][0]',
#                                                                      'dropout[38][0]',
#                                                                      'dropout[39][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 11, 16)           64        ['conv2d_1[30][0]',
#  chNormalization)                                                    'conv2d_1[31][0]',
#                                                                      'conv2d_1[32][0]',
#                                                                      'conv2d_1[33][0]',
#                                                                      'conv2d_1[34][0]',
#                                                                      'conv2d_1[35][0]',
#                                                                      'conv2d_1[36][0]',
#                                                                      'conv2d_1[37][0]',
#                                                                      'conv2d_1[38][0]',
#                                                                      'conv2d_1[39][0]']
#
#  activation_1 (Activation)   (None, 16, 11, 16)           0         ['batch_normalization_1[30][0]
#                                                                     ',
#                                                                      'batch_normalization_1[31][0]
#                                                                     ',
#                                                                      'batch_normalization_1[32][0]
#                                                                     ',
#                                                                      'batch_normalization_1[33][0]
#                                                                     ',
#                                                                      'batch_normalization_1[34][0]
#                                                                     ',
#                                                                      'batch_normalization_1[35][0]
#                                                                     ',
#                                                                      'batch_normalization_1[36][0]
#                                                                     ',
#                                                                      'batch_normalization_1[37][0]
#                                                                     ',
#                                                                      'batch_normalization_1[38][0]
#                                                                     ',
#                                                                      'batch_normalization_1[39][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 2, 16)             0         ['activation_1[30][0]',
#  g2D)                                                                'activation_1[31][0]',
#                                                                      'activation_1[32][0]',
#                                                                      'activation_1[33][0]',
#                                                                      'activation_1[34][0]',
#                                                                      'activation_1[35][0]',
#                                                                      'activation_1[36][0]',
#                                                                      'activation_1[37][0]',
#                                                                      'activation_1[38][0]',
#                                                                      'activation_1[39][0]']
#
#  dropout_1 (Dropout)         (None, 4, 2, 16)             0         ['max_pooling2d_1[30][0]',
#                                                                      'max_pooling2d_1[31][0]',
#                                                                      'max_pooling2d_1[32][0]',
#                                                                      'max_pooling2d_1[33][0]',
#                                                                      'max_pooling2d_1[34][0]',
#                                                                      'max_pooling2d_1[35][0]',
#                                                                      'max_pooling2d_1[36][0]',
#                                                                      'max_pooling2d_1[37][0]',
#                                                                      'max_pooling2d_1[38][0]',
#                                                                      'max_pooling2d_1[39][0]']
#
#  flatten (Flatten)           (None, 128)                  0         ['dropout_1[30][0]',
#                                                                      'dropout_1[31][0]',
#                                                                      'dropout_1[32][0]',
#                                                                      'dropout_1[33][0]',
#                                                                      'dropout_1[34][0]',
#                                                                      'dropout_1[35][0]',
#                                                                      'dropout_1[36][0]',
#                                                                      'dropout_1[37][0]',
#                                                                      'dropout_1[38][0]',
#                                                                      'dropout_1[39][0]']
#
#  dense (Dense)               (None, 30)                   3870      ['flatten[30][0]',
#                                                                      'flatten[31][0]',
#                                                                      'flatten[32][0]',
#                                                                      'flatten[33][0]',
#                                                                      'flatten[34][0]',
#                                                                      'flatten[35][0]',
#                                                                      'flatten[36][0]',
#                                                                      'flatten[37][0]',
#                                                                      'flatten[38][0]',
#                                                                      'flatten[39][0]']
#
#  batch_normalization_2 (Bat  (None, 30)                   120       ['dense[30][0]',
#  chNormalization)                                                    'dense[31][0]',
#                                                                      'dense[32][0]',
#                                                                      'dense[33][0]',
#                                                                      'dense[34][0]',
#                                                                      'dense[35][0]',
#                                                                      'dense[36][0]',
#                                                                      'dense[37][0]',
#                                                                      'dense[38][0]',
#                                                                      'dense[39][0]']
#
#  activation_2 (Activation)   (None, 30)                   0         ['batch_normalization_2[30][0]
#                                                                     ',
#                                                                      'batch_normalization_2[31][0]
#                                                                     ',
#                                                                      'batch_normalization_2[32][0]
#                                                                     ',
#                                                                      'batch_normalization_2[33][0]
#                                                                     ',
#                                                                      'batch_normalization_2[34][0]
#                                                                     ',
#                                                                      'batch_normalization_2[35][0]
#                                                                     ',
#                                                                      'batch_normalization_2[36][0]
#                                                                     ',
#                                                                      'batch_normalization_2[37][0]
#                                                                     ',
#                                                                      'batch_normalization_2[38][0]
#                                                                     ',
#                                                                      'batch_normalization_2[39][0]
#                                                                     ']
#
#  reshape_45 (Reshape)        (None, 1, 30)                0         ['activation_2[30][0]']
#
#  reshape_46 (Reshape)        (None, 1, 30)                0         ['activation_2[31][0]']
#
#  reshape_48 (Reshape)        (None, 1, 30)                0         ['activation_2[32][0]']
#
#  reshape_49 (Reshape)        (None, 1, 30)                0         ['activation_2[33][0]']
#
#  reshape_51 (Reshape)        (None, 1, 30)                0         ['activation_2[34][0]']
#
#  reshape_52 (Reshape)        (None, 1, 30)                0         ['activation_2[35][0]']
#
#  reshape_54 (Reshape)        (None, 1, 30)                0         ['activation_2[36][0]']
#
#  reshape_55 (Reshape)        (None, 1, 30)                0         ['activation_2[37][0]']
#
#  reshape_57 (Reshape)        (None, 1, 30)                0         ['activation_2[38][0]']
#
#  reshape_58 (Reshape)        (None, 1, 30)                0         ['activation_2[39][0]']
#
#  concatenate_18 (Concatenat  (None, 2, 30)                0         ['reshape_45[0][0]',
#  e)                                                                  'reshape_46[0][0]']
#
#  concatenate_19 (Concatenat  (None, 2, 30)                0         ['reshape_48[0][0]',
#  e)                                                                  'reshape_49[0][0]']
#
#  concatenate_20 (Concatenat  (None, 2, 30)                0         ['reshape_51[0][0]',
#  e)                                                                  'reshape_52[0][0]']
#
#  concatenate_21 (Concatenat  (None, 2, 30)                0         ['reshape_54[0][0]',
#  e)                                                                  'reshape_55[0][0]']
#
#  concatenate_22 (Concatenat  (None, 2, 30)                0         ['reshape_57[0][0]',
#  e)                                                                  'reshape_58[0][0]']
#
#  reshape_47 (Reshape)        (None, 1, 60)                0         ['concatenate_18[0][0]']
#
#  reshape_50 (Reshape)        (None, 1, 60)                0         ['concatenate_19[0][0]']
#
#  reshape_53 (Reshape)        (None, 1, 60)                0         ['concatenate_20[0][0]']
#
#  reshape_56 (Reshape)        (None, 1, 60)                0         ['concatenate_21[0][0]']
#
#  reshape_59 (Reshape)        (None, 1, 60)                0         ['concatenate_22[0][0]']
#
#  concatenate_23 (Concatenat  (None, 5, 60)                0         ['reshape_47[0][0]',
#  e)                                                                  'reshape_50[0][0]',
#                                                                      'reshape_53[0][0]',
#                                                                      'reshape_56[0][0]',
#                                                                      'reshape_59[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 5, 30)                9120      ['concatenate_23[0][0]']
#  onal)
#
#  dense_4 (Dense)             (None, 5, 3)                 93        ['bidirectional_3[0][0]']
#
# ==================================================================================================
# Total params: 14547 (56.82 KB)
# Trainable params: 14439 (56.40 KB)
# Non-trainable params: 108 (432.00 Byte)
# __________________________________________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# Train the model

# %%
#change this to true to train the model again
if False:
    checkpoint = ModelCheckpoint('model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='rmsprop')
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=3)
    history = model.fit([X1_train, X2_train, X3_train, X4_train, X5_train],
                        y_train,
                        batch_size=BATCH_SIZE,
                        epochs=20,
                        validation_data=([X1_val, X2_val, X3_val, X4_val, X5_val], y_val),
                        callbacks=[earlystop, checkpoint, CSVLogger('history.csv')],
                        verbose=1)


model = load_model('model.h5')
history = pd.read_csv('history.csv')

# %% [markdown]
# Plot the loss and accuracy. Note that early stopping saved the model after epoch 8

# %%
#plot the training and validation loss
plt.subplots(figsize=(10,6))
plt.plot(history['loss'], '*-', label='Training Loss')
plt.plot(history['val_loss'], '*-', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc=1)
plt.tight_layout()
plt.savefig('loss.png', dpi=150)
plt.show()

#plot the training and validation accuracy
plt.subplots(figsize=(10,6))
plt.plot(history['categorical_accuracy']*100, '*-', label='Training Accuracy')
plt.plot(history['val_categorical_accuracy']*100, '*-', label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (Percent)')
plt.legend(loc=1)
plt.tight_layout()
plt.savefig('accuracy.png', dpi=150)
plt.show()

# %% [markdown]
# Evaluate the model on the test set

# %%
X1_test, X2_test, X3_test, X4_test, X5_test, y_test = load_data('test')
predictions = model.predict([X1_test, X2_test, X3_test, X4_test, X5_test])

#calculate confusion matrix and f1 scores
conf_mat, f1, _, _ = performance_metrics(y_test, predictions, ['Wake', 'NREM', 'REM'])

print('Confusion Matrix:')
print(conf_mat)

print('\nf1 score, per class:')
print(f1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 22 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> X1_test, X2_test, X3_test, X4_test, X5_test, y_test = load_data('test')
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> predictions = model.predict([X1_test, X2_test, X3_test, X4_test, X5_test])
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> #calculate confusion matrix and f1 scores
#
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 22 line load_data(data_group)
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> def load_data(data_group):
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>     data = pickle.load(open('D:\\Sleep Stage Scoring\\lstm-cnn-eeg-sleep-staging\\data\\SC4642EP.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a>     labels = pickle.load(open('D:\\Sleep Stage Scoring\\lstm-cnn-eeg-sleep-staging\\data\\ST7241JO.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a>     #combine NREM1, NREM2, NREM3, and NREM4 into a single class
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=5'>6</a>     #new class definitions:
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a>     #Wake = 0 originally, this remains the same
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=7'>8</a>     #N1 = 1, N2 = 2, N3 = 3, N4 = 4 originally, now they are all assigned to the label of 1
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=8'>9</a>     #REM = 5 originally, now REM = 2
#      <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X30sZmlsZQ%3D%3D?line=9'>10</a>     #Artifact/Unlabeled: N/A as any such labels were already removed in spectrogram generation
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# Generate an example output hypnogram and compare against the true values. This corresponds to subject SC4121EC from the test set.

# %%
#get the predicted hypnogram for test set subject ST7152JA
X1_ST7152JA, X2_ST7152JA, X3_ST7152JA, X4_ST7152JA, X5_ST7152JA, y_ST7152JA = load_data('ST7152JA')
predictions = model.predict([X1_ST7152JA, X2_ST7152JA, X3_ST7152JA, X4_ST7152JA, X5_ST7152JA])

_, _, predictions_class, true_class = performance_metrics(y_ST7152JA, predictions, ['Wake', 'NREM', 'REM'])
fig, ax = plt.subplots(figsize=(10,6))
zero_time = datetime.datetime(2021,1,1,12,59,0)
timestamps = np.array([zero_time+datetime.timedelta(seconds=i*30) for i in range(len(predictions_class))])
plt.plot(timestamps, true_class, label='True Label')
plt.plot(timestamps, predictions_class, 'r--', label='Predicted Label')
plt.legend(loc=0)
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
plt.xticks(rotation=70)
ax.set_yticks([0,1,2])
ax.set_yticklabels(['Wake', 'NREM', 'REM'])
plt.xlabel('Time (HH:MM)')
plt.title('Hypnogram: ST7152JA')
plt.tight_layout()
plt.savefig('ST7152JA_hypnogram.png', dpi=250)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 24 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> #get the predicted hypnogram for test set subject ST7152JA
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> X1_ST7152JA, X2_ST7152JA, X3_ST7152JA, X4_ST7152JA, X5_ST7152JA, y_ST7152JA = load_data('ST7152JA')
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> predictions = model.predict([X1_ST7152JA, X2_ST7152JA, X3_ST7152JA, X4_ST7152JA, X5_ST7152JA])
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> _, _, predictions_class, true_class = performance_metrics(y_ST7152JA, predictions, ['Wake', 'NREM', 'REM'])
#
# d:\Sleep Stage Scoring\lstm-cnn-eeg-sleep-staging\train_model.ipynb Cell 24 line load_data(data_group)
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> def load_data(data_group):
# ----> <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>     data = pickle.load(open('D:\\Sleep Stage Scoring\\lstm-cnn-eeg-sleep-staging\\data\\SC4642EP.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>     labels = pickle.load(open('D:\\Sleep Stage Scoring\\lstm-cnn-eeg-sleep-staging\\data\\ST7241JO.pkl' % data_group, 'rb'))
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>     #combine NREM1, NREM2, NREM3, and NREM4 into a single class
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a>     #new class definitions:
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a>     #Wake = 0 originally, this remains the same
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a>     #N1 = 1, N2 = 2, N3 = 3, N4 = 4 originally, now they are all assigned to the label of 1
#       <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a>     #REM = 5 originally, now REM = 2
#      <a href='vscode-notebook-cell:/d%3A/Sleep%20Stage%20Scoring/lstm-cnn-eeg-sleep-staging/train_model.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a>     #Artifact/Unlabeled: N/A as any such labels were already removed in spectrogram generation
#
# TypeError: not all arguments converted during string formatting
